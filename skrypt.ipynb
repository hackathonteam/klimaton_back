# %% [markdown]
# # Main EDA notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
zuzycie_wody = pd.read_excel("data/01zuzycie.xlsx")

# %%
zuzycie_wody=zuzycie_wody.drop(axis=0, labels=[x for x in range(146,200)])
zuzycie_wody=zuzycie_wody.drop(axis=0, labels=[0,1])
zuzycie_wody = zuzycie_wody.iloc[: , :-1]

# %%
zuzycie_wody
# Out:
#        Lp. Nr licznika wody          Osoba zgłaszająca  \
# 2      1.0      H21KA008618         Katarzyna Gątarska
# 3      2.0      C18UA124562           Sylwia Gadzińska
# 4      3.0      H21KA003461              Sylwia Popłek
# 5      4.0      H21KA012115        Zbigniew Kopczyński
# 6      5.0      C19UA113683  Monika Jeżewska-Andraszyk
# ..     ...              ...                        ...
# 141  140.0      C19UA003383             Piotr Węgierek
# 142  141.0      C17UA110048                Zosia Janas
# 143  142.0      H21KA009918           Mikołaj Serwatka
# 144  143.0       C18UA00362                 Wacław Jeż
# 145  144.0      H21KA006667                 Henryk Wąs
#
#     Adres licznika\n* tożsamy z adresem zbiornika  Zuzycie wody**\n[m3]  \
# 2                                  Roosevelta 164                  10.5
# 3                                 Paczkowskiego 6                   8.5
# 4                                    Kłeckoska 84                  15.0
# ...

# %%
zuzycie_wody.describe()
# Out:
#               Lp.  Zuzycie wody**\n[m3]  \
# count  144.000000            144.000000
# mean    72.500000             11.193056
# std     41.713307              3.034249
# min      1.000000              5.800000
# 25%     36.750000              9.000000
# 50%     72.500000             11.000000
# 75%    108.250000             12.500000
# max    144.000000             21.000000
#
#        Średnie zuzycie wody na miesiąc\n[m3/mies]  \
# count                                  144.000000
# mean                                    12.316634
# std                                      3.603134
# min                                      5.771429
# 25%                                      9.742857
# 50%                                     11.828571
# 75%                                     15.314286
# max                                     21.873629
#
#        Dane archiwalne z 35/ 36 miesięcy  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# ...

# %%
for i in range(4,41):
    zuzycie_wody.plot(x=0, y=i, kind='scatter')
# Out:
# C:\Users\Weronisia\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:337: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
# Out:
# Dane archiwalne z 35/ 36 miesięcy    14.531375
# Unnamed: 7                           10.084049
# Unnamed: 8                           14.532201
# Unnamed: 9                           11.120812
# Unnamed: 10                          14.556729
# Unnamed: 11                          10.340972
# Unnamed: 12                          14.460028
# Unnamed: 13                           9.272896
# Unnamed: 14                          14.204944
# Unnamed: 15                           9.167861
# Unnamed: 16                          14.447049
# Unnamed: 17                           9.326604
# Unnamed: 18                          14.699632
# Unnamed: 19                           9.995847
# Unnamed: 20                          14.916403
# Unnamed: 21                           9.993819
# Unnamed: 22                          14.624160
# Unnamed: 23                          10.112729
# Unnamed: 24                          15.325757
# Unnamed: 25                           9.321382
# ...

# %%
mean.plot(kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-07afd4bb8d22> in <module>
# ----> 1 mean.plot(kind='scatter')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     900                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     901             else:
# --> 902                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#     903         elif kind in self._series_kinds:
#     904             if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames
